# %%
import numpy as np

# %%
# np.random.seed(42)
rnd1 = np.random.rand(10) * 2
rnd1
# Out:
# array([1.22370579, 0.27898772, 0.5842893 , 0.73272369, 0.91213997,
#        1.57035192, 0.39934756, 1.02846888, 1.18482914, 0.09290083])

# %%
rnd2 = np.random.randint(0,100,10)
rnd2
# Out:
# array([21, 52,  1, 87, 29, 37,  1, 63, 59, 20], dtype=int32)

# %%
a1 = np.array([1,2,3,4])
a1
# Out:
# array([1, 2, 3, 4])

# %%
result = np.sin(a1)
result
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 ])

# %%
for i in a1:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
np.max(a1)
# Out:
# np.int64(4)

# %%
print(a1.ndim, a1.size, a1.shape, a1.dtype)
# Out:
# 1 4 (4,) int64

# %%
a10 = np.arange(100,110)
a10
# Out:
# array([100, 101, 102, 103, 104, 105, 106, 107, 108, 109])

# %%
for v in a10:
    print(v)
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109

# %%
a10[0]
# Out:
# np.int64(100)

# %%
for i in np.arange(len(a10)):
    print(a10[i])
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109

# %%
a10[-2]
# Out:
# np.int64(108)

# %%
a10[2:6]
# Out:
# array([102, 103, 104, 105])

# %%
n=3
a10[n:-n]
# Out:
# array([103, 104, 105, 106])

# %%
a10[-3:-1]
# Out:
# array([107, 108])

# %%
a10[-3:]
# Out:
# array([107, 108, 109])

# %%
a10[:3]
# Out:
# array([100, 101, 102])

# %%
a10[:]
# Out:
# array([100, 101, 102, 103, 104, 105, 106, 107, 108, 109])

# %%
a10[1:-1:2]
# Out:
# array([101, 103, 105, 107])

# %%
a10[::2]
# Out:
# array([100, 102, 104, 106, 108])

# %%
np.flip(a10[::-3])
# Out:
# array([100, 103, 106, 109])
