# %%
import numpy as np

# %%
rnd = np.random.rand(1000)

# %%
np.mean(rnd), np.median(rnd), np.std(rnd), np.quantile(rnd, [0.1,0.25,0.5,0.75,0.9])
# Out:
# (np.float64(0.5081333201202927),
#  np.float64(0.5087892326476856),
#  np.float64(0.2881263242061693),
#  array([0.10653707, 0.26048316, 0.50878923, 0.76456822, 0.89972212]))
