# %%
x = 3
x
# Out:
# 3

# %%
import sys
import numpy

print(sys.version, numpy.__version__)

print("Hello World")
x = 1
y = x + 1
x = x + 1
x += 1
x /= 2 # x = x / 2
print(f"La valeur de x est: {x:.2f}")
# Out:
# 3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)] 2.2.6
# Hello World
# La valeur de x est: 1.50
